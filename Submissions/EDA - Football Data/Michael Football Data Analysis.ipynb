# %% [markdown]
# # Michael Exploratory Data Analysis

# %% [markdown]
# ### Import Data

# %%
import pandas as pd

# %%
# Load data - pass 'Name' as our index column
load_df = pd.read_csv('football_players.csv.csv', index_col='Name')

# Create dataframe called df
df = pd.DataFrame(load_df)

# Use the head() function to look at the first 5 rows
df.head()
# Out:
# C:\Users\NICKCLAUS\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (14,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# L. Messi            30   Argentina       93       92         48      90
# Neymar              25      Brazil       92       94         56      96
# L. Suárez           30     Uruguay       92       88         78      86
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...        83
# L. Messi           95           95        96       77      ...        88
# Neymar             82           95        92       75      ...        81
# L. Suárez          60           91        83       77      ...        83
# M. Neuer           35           48        70       15      ...        55
#
#                   Shot power Sliding tackle Sprint speed Stamina  \
# Name
# Cristiano Ronaldo     94             23           91      92
# L. Messi              85             26           87      73
# Neymar                80             33           90      78
# L. Suárez             87             38           77      89
# M. Neuer              25             11           61      44
#
#                   Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# Cristiano Ronaldo          31       80      85      88                  ST LW
# L. Messi                   28       59      90      85                     RW
# Neymar                     24       53      80      83                     LW
# L. Suárez                  45       80      84      88                     ST
# M. Neuer                   10       83      70      11                     GK
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Position Type Column

# %%
def position_type(s):
    
    """This function converts the individual positions (abbreviations) and classfies it
    as either a forward, midfielder, back or goal keeper"""
    
    if (s[-2] == 'T') | (s[-2] == 'W'):
        return 'Forward'
    elif s[-2] == 'M':
        return 'Midfielder'
    elif s[-2] == 'B':
        return 'Back'
    else:
        return 'GoalKeeper'

# Create position type column
df['Preferred Positions Type'] = df['Preferred Positions'].apply(position_type)

# %% [markdown]
# ### Attribute Columns to Floats

# %%
# Select all attribute columns
cols = ['Overall', 'Acceleration', 'Aggression',
       'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve',
       'Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving',
       'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes',
       'Heading accuracy', 'Interceptions', 'Jumping', 'Long passing',
       'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions',
       'Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed',
       'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys']

def to_float(x):    
    "Transforms attribute columns to type float"
    
    if type(x) is int:
        return float(x)
    else:
        return float(x[0:2])

df[cols] = df[cols].applymap(to_float)

# %%
df=pd.read_csv('football_players.csv.csv')
df.head()
# Out:
#                 Name  Age Nationality  Overall Acceleration Aggression  \
# 0  Cristiano Ronaldo   32    Portugal       94       89         63
# 1           L. Messi   30   Argentina       93       92         48
# 2             Neymar   25      Brazil       92       94         56
# 3          L. Suárez   30     Uruguay       92       88         78
# 4           M. Neuer   31     Germany       92       58         29
#
#   Agility Balance Ball control Composure  ... Short passing Shot power  \
# 0  89      63           93        95      ...        83         94
# 1  90      95           95        96      ...        88         85
# 2  96      82           95        92      ...        81         80
# 3  86      60           91        83      ...        83         87
# 4  52      35           48        70      ...        55         25
#
#   Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 0         23           91      92              31       80      85
# 1         26           87      73              28       59      90
# 2         33           90      78              24       53      80
# 3         38           77      89              45       80      84
# 4         11           61      44              10       83      70
#
#   Volleys Preferred Positions
# 0  88                  ST LW
# 1  85                     RW
# 2  83                     LW
# 3  88                     ST
# 4  11                     GK
#
# [5 rows x 39 columns]

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Acceleration', 'Aggression',
#        'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve',
#        'Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving',
#        'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes',
#        'Heading accuracy', 'Interceptions', 'Jumping', 'Long passing',
#        'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions',
#        'Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed',
#        'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys',
#        'Preferred Positions'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 39 columns):
# Name                   17981 non-null object
# Age                    17981 non-null int64
# Nationality            17981 non-null object
# Overall                17981 non-null int64
# Acceleration           17981 non-null object
# Aggression             17981 non-null object
# Agility                17981 non-null object
# Balance                17981 non-null object
# Ball control           17981 non-null object
# Composure              17981 non-null object
# Crossing               17981 non-null object
# Curve                  17981 non-null object
# Dribbling              17981 non-null object
# Finishing              17981 non-null object
# Free kick accuracy     17981 non-null object
# GK diving              17981 non-null object
# GK handling            17981 non-null object
# GK kicking             17981 non-null object
# GK positioning         17981 non-null object
# GK reflexes            17981 non-null object
# Heading accuracy       17981 non-null object
# Interceptions          17981 non-null object
# Jumping                17981 non-null object
# Long passing           17981 non-null object
# Long shots             17981 non-null object
# Marking                17981 non-null object
# Penalties              17981 non-null object
# Positioning            17981 non-null object
# Reactions              17981 non-null object
# Short passing          17981 non-null object
# Shot power             17981 non-null object
# Sliding tackle         17981 non-null object
# Sprint speed           17981 non-null object
# Stamina                17981 non-null object
# Standing tackle        17981 non-null object
# Strength               17981 non-null object
# Vision                 17981 non-null object
# Volleys                17981 non-null object
# Preferred Positions    17981 non-null object
# dtypes: int64(2), object(37)
# memory usage: 5.4+ MB

# %% [markdown]
# ### Accessing By Column

# %%
# Column 'Age'
df['Age']
# Out:
# 0        32
# 1        30
# 2        25
# 3        30
# 4        31
# 5        28
# 6        26
# 7        26
# 8        27
# 9        29
# 10       31
# 11       26
# 12       25
# 13       28
# 14       31
# 15       27
# 16       29
# 17       32
# 18       39
# 19       23
# 20       24
# 21       26
# 22       26
# 23       28
# 24       30
# 25       28
# 26       31
# 27       28
# 28       28
# 29       30
#          ..
# 17951    21
# 17952    17
# 17953    18
# 17954    19
# 17955    18
# 17956    17
# 17957    17
# 17958    17
# 17959    18
# 17960    18
# 17961    17
# 17962    18
# 17963    19
# 17964    18
# 17965    18
# 17966    18
# 17967    19
# 17968    17
# 17969    18
# 17970    19
# 17971    18
# 17972    19
# 17973    18
# 17974    18
# 17975    28
# 17976    17
# 17977    47
# 17978    17
# 17979    18
# 17980    18
# Name: Age, Length: 17981, dtype: int64

# %%
# Columns 'Age' and 'Nationality'
df[['Age', 'Nationality']]
# Out:
#        Age          Nationality
# 0       32             Portugal
# 1       30            Argentina
# 2       25               Brazil
# 3       30              Uruguay
# 4       31              Germany
# 5       28               Poland
# 6       26                Spain
# 7       26              Belgium
# 8       27              Germany
# 9       29            Argentina
# 10      31                Spain
# 11      26              Belgium
# 12      25              Belgium
# 13      28                Chile
# 14      31              Croatia
# 15      27                Wales
# 16      29            Argentina
# 17      32                Italy
# 18      39                Italy
# 19      23            Argentina
# 20      24             Slovenia
# 21      26               France
# 22      26                Spain
# 23      28                Gabon
# 24      30                Italy
# 25      28              Germany
# 26      31              Uruguay
# 27      28              Germany
# 28      28              Germany
# 29      30               France
# ...    ...                  ...
# 17951   21             Scotland
# 17952   17        FYR Macedonia
# 17953   18              England
# 17954   19              England
# 17955   18             Scotland
# 17956   17              England
# 17957   17  Republic of Ireland
# 17958   17  Republic of Ireland
# 17959   18             Scotland
# 17960   18  Republic of Ireland
# 17961   17              England
# 17962   18              England
# 17963   19  Republic of Ireland
# 17964   18  Republic of Ireland
# 17965   18  Republic of Ireland
# 17966   18                Japan
# 17967   19              England
# 17968   17              England
# 17969   18              Austria
# 17970   19              England
# 17971   18              England
# 17972   19  Republic of Ireland
# 17973   18              England
# 17974   18              England
# 17975   28              Germany
# 17976   17              England
# 17977   47              England
# 17978   17             Scotland
# 17979   18              England
# 17980   18                Ghana
#
# [17981 rows x 2 columns]

# %% [markdown]
# ### Index and Column

# %%
# The first 5 rows and first 2 columns - Rows first
df.iloc[0:5][['Age', 'Nationality']]
# Out:
#    Age Nationality
# 0   32    Portugal
# 1   30   Argentina
# 2   25      Brazil
# 3   30     Uruguay
# 4   31     Germany

# %% [markdown]
# ### Sorting

# %%
# By age from youngest to oldest (select first 5 entries)
df.sort_values(by='Age').head()
# Out:
#                Name  Age  Nationality  Overall Acceleration Aggression  \
# 15837     J. Romero   16    Argentina       58       75         36
# 17667       J. Hove   16       Norway       51       57         57
# 15571  Javi Vázquez   16        Spain       58       61         53
# 10556     K. Pierie   16  Netherlands       65       72         64
# 17025     L. Pintor   16       France       54       72         29
#
#       Agility Balance Ball control Composure  ... Short passing Shot power  \
# 15837  70      86           55        59      ...        52         54
# 17667  58      56           51        42      ...        56         50
# 15571  48      65           47        43      ...        41         42
# 10556  66      53           65        66      ...        68         35
# 17025  70      68           56        43      ...        30         57
#
#       Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 15837         25           77      58              26       41      51
# 17667         56           64      47              51       54      56
# 15571         59           64      59              63       55      37
# 10556         62           72      45              67       65      56
# 17025         12           68      36              10       34      38
#
#       Volleys Preferred Positions
# 15837  45                     ST
# 17667  29                     CM
# 15571  29                     CB
# 10556  32                  LB CB
# 17025  48                     ST
#
# [5 rows x 39 columns]

# %%
# By age from oldest to youngest (select first 5 entries)
df.sort_values(by='Age', ascending=False).head()
# Out:
#                 Name  Age Nationality  Overall Acceleration Aggression  \
# 17977  B. Richardson   47     England       46       25         44
# 5314    E. El Hadary   44       Egypt       70       28         29
# 4839        O. Pérez   44      Mexico       71       60         26
# 16834      J. Walker   43     England       55       22         41
# 16696       D. Coyne   43       Wales       55       36         36
#
#       Agility Balance Ball control Composure  ... Short passing Shot power  \
# 17977  35      44           22        44      ...        12         13
# 5314   21      41           25        57      ...        16         18
# 4839   69      69           23        50      ...        26         24
# 16834  53      64           38        35      ...        22         22
# 16696  48      58           31        57      ...        28         21
#
#       Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 17977         13           25      32              12       47      17
# 5314          15           39      34              19       73      16
# 4839          11           57      41              12       66      40
# 16834         13           35      19              11       62      32
# 16696         19           33      37              16       76      33
#
#       Volleys Preferred Positions
# 17977  12                     GK
# 5314   12                     GK
# 4839   13                     GK
# 16834  11                     GK
# 16696  11                     GK
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Creating columns

# %%
# Create column of rating per year of age
df['Rating Per Year of Age'] = df['Overall'] / df['Age']

# Look at first 5 entries
df['Rating Per Year of Age'].head()
# Out:
# 0    2.937500
# 1    3.100000
# 2    3.680000
# 3    3.066667
# 4    2.967742
# Name: Rating Per Year of Age, dtype: float64

# %%
df[df.Age == df.Age.max()]
# Out:
#                 Name  Age Nationality  Overall Acceleration Aggression  \
# 17977  B. Richardson   47     England       46       25         44
#
#       Agility Balance Ball control Composure  ... Short passing Shot power  \
# 17977  35      44           22        44      ...        12         13
#
#       Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 17977         13           25      32              12       47      17
#
#       Volleys Preferred Positions
# 17977  12                     GK
#
# [1 rows x 39 columns]

# %%
# %matplotlib inline

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B88C9D72E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B88E7CE160>]],
#       dtype=object)

# %%
df.Balance = pd.to_numeric(df.Balance ,errors = "coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 39 columns):
# Name                   17981 non-null object
# Age                    17981 non-null int64
# Nationality            17981 non-null object
# Overall                17981 non-null int64
# Acceleration           17981 non-null object
# Aggression             17981 non-null object
# Agility                17981 non-null object
# Balance                17941 non-null float64
# Ball control           17981 non-null object
# Composure              17981 non-null object
# Crossing               17981 non-null object
# Curve                  17981 non-null object
# Dribbling              17981 non-null object
# Finishing              17981 non-null object
# Free kick accuracy     17981 non-null object
# GK diving              17981 non-null object
# GK handling            17981 non-null object
# GK kicking             17981 non-null object
# GK positioning         17981 non-null object
# GK reflexes            17981 non-null object
# Heading accuracy       17981 non-null object
# Interceptions          17981 non-null object
# Jumping                17981 non-null object
# Long passing           17981 non-null object
# Long shots             17981 non-null object
# Marking                17981 non-null object
# Penalties              17981 non-null object
# Positioning            17981 non-null object
# Reactions              17981 non-null object
# Short passing          17981 non-null object
# Shot power             17981 non-null object
# Sliding tackle         17981 non-null object
# Sprint speed           17981 non-null object
# Stamina                17981 non-null object
# Standing tackle        17981 non-null object
# Strength               17981 non-null object
# Vision                 17981 non-null object
# Volleys                17981 non-null object
# Preferred Positions    17981 non-null object
# dtypes: float64(1), int64(2), object(36)
# memory usage: 5.4+ MB

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B88E8CE080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B88EE03F98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B88EE3D588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B88EE6FB38>]],
#       dtype=object)

# %%
df.Balance.max()
# Out:
# 31472.0

# %%
df.head(50)
# Out:
#                  Name  Age  Nationality  Overall Acceleration Aggression  \
# 0   Cristiano Ronaldo   32     Portugal       94       89         63
# 1            L. Messi   30    Argentina       93       92         48
# 2              Neymar   25       Brazil       92       94         56
# 3           L. Suárez   30      Uruguay       92       88         78
# 4            M. Neuer   31      Germany       92       58         29
# 5      R. Lewandowski   28       Poland       91       79         80
# 6              De Gea   26        Spain       90       57         38
# 7           E. Hazard   26      Belgium       90       93         54
# 8            T. Kroos   27      Germany       90       60         60
# 9          G. Higuaín   29    Argentina       90       78         50
# 10       Sergio Ramos   31        Spain       90       75         84
# 11       K. De Bruyne   26      Belgium       89       76         68
# 12        T. Courtois   25      Belgium       89       46         23
# 13         A. Sánchez   28        Chile       89       88         80
# 14          L. Modrić   31      Croatia       89       75         62
# 15            G. Bale   27        Wales       89       93         65
# 16          S. Agüero   29    Argentina       89       90         63
# 17       G. Chiellini   32        Italy       89       68         92
# 18          G. Buffon   39        Italy       89       49         38
# 19          P. Dybala   23    Argentina       88       88         48
# 20           J. Oblak   24     Slovenia       88       43         34
# 21       A. Griezmann   26       France       88       87         69
# 22             Thiago   26        Spain       88       77         57
# 23      P. Aubameyang   28        Gabon       88       95         43
# 24         L. Bonucci   30        Italy       88       62         82
# 25         J. Boateng   28      Germany       88       72         82
# 26           D. Godín   31      Uruguay       88       62         86
# 27         M. Hummels   28      Germany       88       62         66
# 28            M. Özil   28      Germany       88       75         48
# 29          H. Lloris   30       France       88       65         31
# 30       Thiago Silva   32       Brazil       88       70         77
# 31     Z. Ibrahimović   35       Sweden       88       63         84
# 32          A. Robben   33  Netherlands       88       87         47
# 33           N. Kanté   26       France       87       82         90
# 34        M. Verratti   24        Italy       87       69         89
# 35           P. Pogba   24       France       87       72         75
# 36         C. Eriksen   25      Denmark       87       77         44
# 37           A. Vidal   30        Chile       87       76         93
# 38          E. Cavani   30      Uruguay       87       75         84
# 39            Marcelo   29       Brazil       87       77         84
# 40          M. Hamšík   29     Slovakia       87       72         56
# 41         I. Rakitić   29      Croatia       87       67         67
# 42        David Silva   31        Spain       87       72         51
# 43      S. Handanovič   32     Slovenia       87       54         25
# 44              Piqué   30        Spain       87       55         72
# 45            Iniesta   33        Spain       87       72         58
# 46            H. Kane   23      England       86       68         74
# 47       J. Rodríguez   25     Colombia       86       77         65
# 48               Isco   25        Spain       86       74         58
# 49           D. Alaba   25      Austria       86       86         69
#
#    Agility  Balance Ball control Composure  ... Short passing Shot power  \
# 0   89         63.0       93        95      ...        83         94
# 1   90         95.0       95        96      ...        88         85
# 2   96         82.0       95        92      ...        81         80
# 3   86         60.0       91        83      ...        83         87
# 4   52         35.0       48        70      ...        55         25
# 5   78         80.0       89        87      ...        83         88
# 6   60         43.0       42        64      ...        50         31
# 7   93         91.0       92        87      ...        86         79
# 8   71         69.0       89        85      ...        90         87
# 9   75         69.0       85        86      ...        75         88
# 10  79         60.0       84        80      ...        78         79
# 11  80         75.0       87        84      ...        90         85
# 12  61         45.0       23        52      ...        32         36
# 13  90         87.0       87        86      ...        81         84
# 14  93         94.0       92        84      ...        92         73
# 15  77         65.0       87        85      ...        86         91
# 16  86         91.0       89        90      ...        79         88
# 17  59         64.0       57        82      ...        59         78
# 18  55         49.0       28        70      ...        37         39
# 19  91         85.0       93        84      ...        83         82
# 20  67         49.0       16        55      ...        29         22
# 21  90         80.0       86        86      ...        79         81
# 22  90         86.0       92        83      ...        91         75
# 23  77         70.0       82        84      ...        77         81
# 24  60         52.0       75        84      ...        79         74
# 25  58         53.0       71        86      ...        75         79
# 26  63         58.0       76        82      ...        79         67
# 27  64         58.0       77        91      ...        80         71
# 28  83         70.0       90        78      ...        89         70
# 29  55         54.0       34        61      ...        50         23
# 30  74         68.0       80        83      ...        79         74
# 31  81         41.0       88        91      ...        84         91
# 32  89         91.0       89        86      ...        84         87
# 33  83         90.0       79        84      ...        84         72
# 34  87         94.0       88        91      ...        90         56
# 35  76         61.0       89        85      ...        86         90
# 36  78         82.0       87        87      ...        89         80
# 37  75         77.0       83        86      ...        84         86
# 38  81         59.0       80        83      ...        78         85
# 39  77         82.0       88        85      ...        82         83
# 40  76         66.0       87        84      ...        88         82
# 41  72         66.0       87        81      ...        87         84
# 42  92         89.0       90        92      ...        91         71
# 43  42         36.0       24        62      ...        36         22
# 44  58         42.0       78        86      ...        81         62
# 45  79         84.0       94        89      ...        92         65
# 46  73         62.0       82        84      ...        75         87
# 47  82         75.0       85        87      ...        84         86
# 48  83         85.0       91        86      ...        86         72
# 49  79         77.0       83        79      ...        83         83
#
#    Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 0          23           91      92              31       80      85
# 1          26           87      73              28       59      90
# 2          33           90      78              24       53      80
# 3          38           77      89              45       80      84
# 4          11           61      44              10       83      70
# 5          19           83      79              42       84      78
# 6          13           58      40              21       64      68
# 7          22           87      79              27       65      86
# 8          69           52      77              82       74      88
# 9          18           80      72              22       85      70
# 10         91           77      84              89       81      63
# 11         40           75      87              51       73      90
# 12         16           52      38              18       70      44
# 13         35           84      85              39       72      83
# 14         73           71      82              80       58      90
# 15         52           95      76              55       80      79
# 16         12           84      74              20       74      83
# 17         90           78      68              92       91      50
# 18         11           43      39              11       69      50
# 19         20           84      83              20       65      84
# 20         18           60      41              12       78      55
# 21         11           86      76              22       61      76
# 22         62           68      75              64       59      86
# 23         36           96      79              25       77      77
# 24         88           72      73              88       85      74
# 25         90           78      74              91       91      76
# 26         89           67      67              86       80      52
# 27         90           65      66              92       85      79
# 28         19           68      69              16       57      92
# 29         18           63      41              10       43      30
# 30         88           74      74              89       81      74
# 31         27           67      71              41       88      83
# 32         26           86      68              26       67      83
# 33         85           80      94              89       77      76
# 34         79           62      77              84       56      88
# 35         66           76      91              68       91      86
# 36         22           74      90              56       57      90
# 37         85           74      91              89       77      80
# 38         27           78      92              45       74      77
# 39         87           79      81              85       77      75
# 40         62           75      85              73       69      86
# 41         53           64      76              65       63      87
# 42         29           65      78              44       56      92
# 43         13           57      41              10       71      41
# 44         86           73      66              87       83      62
# 45         56           71      58              57       58      94
# 46         38           74      85              36       86      75
# 47         30           75      68              42       70      86
# 48         51           69      71              73       59      84
# 49         83           86      87              83       69      78
#
#    Volleys Preferred Positions
# 0   88                  ST LW
# 1   85                     RW
# 2   83                     LW
# 3   88                     ST
# 4   11                     GK
# 5   87                     ST
# 6   13                     GK
# 7   79                     LW
# 8   82                 CDM CM
# 9   88                     ST
# 10  66                     CB
# 11  82              RM CM CAM
# 12  12                     GK
# 13  83            RM LW ST LM
# 14  74                 CDM CM
# 15  76                     RW
# 16  85                     ST
# 17  45                     CB
# 18  17                     GK
# 19  88                 ST CAM
# 20  13                     GK
# 21  87               LW RW ST
# 22  90             CDM CAM CM
# 23  86                     ST
# 24  58                     CB
# 25  53                     CB
# 26  47                     CB
# 27  60                     CB
# 28  77                 RW CAM
# 29  11                     GK
# 30  63                     CB
# 31  90                     ST
# 32  86                  RW RM
# 33  56                 CM CDM
# 34  64                 CDM CM
# 35  85                 CDM CM
# 36  74              LM RM CAM
# 37  78                 CM CDM
# 38  84                     ST
# 39  54                     LB
# 40  79                     CM
# 41  80                     CM
# 42  79              LM CM CAM
# 43  12                     GK
# 44  57                     CB
# 45  74                  LM CM
# 46  73                     ST
# 47  91              RM CM CAM
# 48  64           LM RM CAM CM
# 49  68               CM CB LB
#
# [50 rows x 39 columns]

# %%
df.sort_values('Balance',ascending=False)
# Out:
#                      Name  Age       Nationality  Overall Acceleration  \
# 9730             T. Kløve   26           Denmark       66       79
# 11818         D. Buchanan   31  Northern Ireland       64       64
# 9036           C. Quiring   26           Germany       66       86
# 15123           B. Waters   22           England       59       81
# 16350                Dudu   21            Brazil       57       74
# 10012          P. Pawlett   26          Scotland       65       83
# 10639            E. Upson   27           England       65       64
# 16216         A. Fletcher   18           England       57         75+4
# 9242       H. Bernardello   30         Argentina       66       51
# 15622        N. Czornomaz   21         Argentina       58    21551
# 4562           M. Riemann   28           Germany       71       53
# 17713               P. Ng   21           England       51         62+1
# 9046          B. Brereton   18           England       66       88
# 13380           N. Bishop   35           England       62       66
# 3585     Carlos Hernández   26             Spain       72    21459
# 12215            M. Owusu   22           Germany       63       72
# 2128            N. Araujo   25            Mexico       74       66
# 5745           E. Oztumer   26           England       70       88
# 559               Bernard   24            Brazil       79       94
# 1                L. Messi   30         Argentina       93       92
# 15290          S. Wharton   19           England       59       68
# 15815          K. Kadyrov   23            Russia       58       72
# 2502               M. Sau   29             Italy       74       89
# 6102           J. Kosecki   26            Poland       69       93
# 930          P. De Blasis   29         Argentina       77       87
# 8980           S. Horvath   20           Austria       66       74
# 3558               Ismael   22            Brazil       72       72
# 301        Gelson Martins   22          Portugal       81       95
# 5961           C. Techera   25           Uruguay       69       80
# 11053           D. Brooks   19             Wales       64       66
# ...                   ...  ...               ...      ...          ...
# 2798               Joselu   26             Spain       73       78
# 4896             F. Mendy   22            France       70         80+2
# 5807             S. Janko   21       Switzerland       69       90
# 6898             A. Yasin   26              Iraq       68       78
# 7898          J. Blackman   23           England       67    15738
# 7994               O. Sow   27            Sweden       67       75
# 8099           R. Kurzawa   24            Poland       67       51
# 8368             D. Badji   24           Senegal       67         77+3
# 8418           D. Kądzior   25            Poland       67        82+10
# 8899        M. O'Halloran   26          Scotland       66       94
# 9033          A. Portales   21            Mexico       66       63
# 9287           S. O'Neill   23     United States       66    25600
# 9677            D. Sallói   20           Hungary       66       75
# 9786            N. Trujic   25            Serbia       66       75
# 10322        S. Żurkowski   19            Poland       65       68
# 11465          Manel Royo   23             Spain       64         64+5
# 11632           L. Zidane   19            France       64        33+10
# 11883             J. Leko   18           England       64       88
# 12032         R. te Loeke   28       Netherlands       63       42
# 12435           R. Seager   21           England       63       70
# 14165         G. Williams   24           England       61       75
# 14311           I. Ganago   18          Cameroon       61         67+2
# 14511            K. Scott   19     United States       60         61+3
# 14838          A. Nesbitt   20          Scotland       60       73
# 14972     Gonzalo Pereira   20             Spain       60         59+1
# 15344           G. Cooper   20           England       59       76
# 15360        J. Schneider   23           Germany       59        78+14
# 16123  T. Adebayo-Rowling   20           England       57       74
# 17506         T. Bakinson   18           England       52       62
# 17764         C. Brittain   19           England       51       70
#
#       Aggression    Agility  Balance Ball control  Composure  ...  \
# 9730      43      26299      31472.0       68         72      ...
# 11818     69         71      29587.0       58         63      ...
# 9036      63      30164      29373.0    22341      21582      ...
# 15123     43         81      28856.0       59         42      ...
# 16350     31         70      26724.0       56         57      ...
# 10012       56+1     82      26665.0       64         55      ...
# 10639  26330         71      26330.0       70      24838      ...
# 16216     49           77+2  24929.0       54         56      ...
# 9242      70      22341      24504.0       68         64      ...
# 15622  43130      18264      23043.0    23377      19025      ...
# 4562      40         45      22282.0         38+3     60      ...
# 17713     48         41      21186.0         38+1       45+2  ...
# 9046       67+39     75      20637.0       68          64+24  ...
# 13380     76         67      20149.0       62         52      ...
# 3585      70      18476      19025.0    21610         65      ...
# 12215     58         67      18384.0       67         57      ...
# 2128      68      15766      17227.0         66+1     71      ...
# 5745      65         93         96.0       70         76      ...
# 559       41         92         96.0       84         71      ...
# 1         48         90         95.0       95         96      ...
# 15290     54         48         95.0       38         45      ...
# 15815     31         92         95.0       59         52      ...
# 2502      38         93         95.0       76         78      ...
# 6102      72         92         95.0       71         75      ...
# 930       72         93         95.0       80         74      ...
# 8980      60         86         94.0       72         51      ...
# 3558      78         84         94.0       77         71      ...
# 301       57         94         94.0       83         84      ...
# 5961      55         90         94.0       70         63      ...
# 11053     51         75         94.0       65         58      ...
# ...          ...        ...      ...          ...        ...  ...
# 2798      69      24869          NaN       68         63      ...
# 4896        76+7       70+3      NaN         68+6       72+6  ...
# 5807        66+3       65+4      NaN         64+1       61+2  ...
# 6898      68         82          NaN         71+2     70      ...
# 7898        23+3      46+13      NaN       25           28+4  ...
# 7994      55         71          NaN       68         70      ...
# 8099      39           70+1      NaN         68+1     62      ...
# 8368      65           67+8      NaN         66+3       61+2  ...
# 8418      52           83+6      NaN       66         62      ...
# 8899      31           85+2      NaN         63+3       62+3  ...
# 9033        67+6     62          NaN       55         45      ...
# 9287   24504         57          NaN       63         59      ...
# 9677      65         71          NaN         66+3       63+3  ...
# 9786        33+2     59          NaN       62         52      ...
# 10322     55         57          NaN         66+2     72      ...
# 11465     64           60+7      NaN        56+14     56      ...
# 11632     16           36+2      NaN       14         36      ...
# 11883     30         82          NaN       63         55      ...
# 12032     23         55          NaN       21         39      ...
# 12435     34         58          NaN       60         62      ...
# 14165       51+1     73          NaN         57+1     48      ...
# 14311     32         58          NaN       52           51+5  ...
# 14511       48+2       72+1      NaN         63+3     62      ...
# 14838       40+2     69          NaN       61         61      ...
# 14972       57+1       49+1      NaN    14246           44+1  ...
# 15344     31         65          NaN       54           56+1  ...
# 15360     43         65          NaN       56         51      ...
# 16123     53         67          NaN       51         48      ...
# 17506     35         58          NaN         57+1     49      ...
# 17764     33         69          NaN         56+2       44+5  ...
#
#       Short passing Shot power Sliding tackle Sprint speed    Stamina  \
# 9730         62         62             41           69         78
# 11818        58         54             66           62         76
# 9036         63         64             20           81         80
# 15123        55         58             47           83         66
# 16350        58      20486             19           76      25385
# 10012        64         62             16           87         74
# 10639     24838         63             62           69         89
# 16216        45         57             11        26724         60
# 9242         70         69             62           45         55
# 15622     22647      23377          12420        21217      17533
# 4562         50         16             12           45         43
# 17713        44         36             55             60+1     57
# 9046         53         67             38           85         72
# 13380        64         57             64           45         71
# 3585      23408           58+9         73        20333         74
# 12215        63         65             21           83         65
# 2128           65+2     63             75             71+1  26359
# 5745         68         68             17           70         76
# 559          76         73             25           84         68
# 1            88         85             26           87         73
# 15290        49         36             61           65         63
# 15815        57         61             22           67         51
# 2502         73         68             22           91         76
# 6102         60         61             25           91         71
# 930          74         75             37           75         77
# 8980         62         59             52           68         66
# 3558         72         67             51           68         77
# 301          75         72             36           94         87
# 5961         61         70             32           75         68
# 11053        69         49             28           63         60
# ...             ...        ...            ...          ...        ...
# 2798         58         82             39        27454      31472
# 4896           65+5      64+29           66+2         80+2     78
# 5807           62+1     66               68+3       87           74+1
# 6898           65+6       70+1           20+2       81         76
# 7898         31         23             12        13789      43433
# 7994         63         70             21        31413         65
# 8099         72         68             58           60           59+3
# 8368           59+4      64+10         34             84+5     74
# 8418         63           63+1         46             77+3     75
# 8899           59+4       69+2         31           92           74+4
# 9033           63+4     39               66+2       62         70
# 9287         65         62             63        24929         71
# 9677          67+13     66             16           78         69
# 9786         46         69             18           77         64
# 10322        67           63+1           60+1         71+5       69+1
# 11465          60+6     48             67            67+12       66+9
# 11632        22         15             13        11689           52+7
# 11883        53         66             23           88         71
# 12032        18         15             13           35         33
# 12435        60         63             21           75         59
# 14165        61         24             63           70         69
# 14311        51         58             14             71+3     58
# 14511          63+2       54+2         51             65+3       60+4
# 14838        59         57             43           67         67
# 14972     13516      16438               70+2         61+1       62+1
# 15344        51         42             27           75           60+2
# 15360        49         61             23             75+8     50
# 16123        51         35             52           73           70+6
# 17506          58+1     52             49           66           58+2
# 17764        44         49             40           76         64
#
#       Standing tackle   Strength     Vision    Volleys Preferred Positions
# 9730           60         55         66      19360                  CM RM
# 11818          67         65           52+1     36                     LB
# 9036           18         41         57         58                     RM
# 15123          45         56         54         54              CAM RM ST
# 16350          19         57         52         49                     ST
# 10012          17         67         65         53              CM RM CAM
# 10639          64      24838         69         38                 CM CDM
# 16216          18         53         41         60                     ST
# 9242           67         62         65         55                 CM CDM
# 15622       43126      20090      18660      18994                     LM
# 4562           14         67         48         13                     GK
# 17713          54         62           30+1     29                  CB RB
# 9046           50         71          62+11     66                  RM ST
# 13380          62         75         58         44                     CM
# 3585             72+1     79         42         27                     CB
# 12215          30          59-19     45         47                  ST RM
# 2128           75      31048         43         36                     CB
# 5745           22         25         69         63                 CF CAM
# 559            39           34+3     77         68                 LW CAM
# 1              28         59         90         85                     RW
# 15290          62         63         33         27                     CB
# 15815          21         28         52         63                  RM LM
# 2502           22         52         74         77                  CF ST
# 6102           30         27         56         62                     LM
# 930            39         47         71         60               ST RM LM
# 8980           47         30         58         54                 CAM LM
# 3558           57         55         76         56                     CM
# 301            46         48         78         74                  LM RM
# 5961            44+10     32           72+4     64                  LM RM
# 11053          38         59         67         50                    CAM
# ...               ...        ...        ...        ...                 ...
# 2798           45         75         48         70                  LM ST
# 4896             67+2       75+1       58+5       39+4                 LB
# 5807             66+3     66         45         38                  RM RB
# 6898             27+4     71         55         59                  ST RW
# 7898           13         58          29+15     17                     GK
# 7994           17         80         59         47                     ST
# 8099           60         59           71+1     60                  CM LM
# 8368           39      27030         52           52+8                 ST
# 8418           45      21094         65         41                     RM
# 8899           21         72         59         58                 RM CAM
# 9033             67+4     75         50         31                     CB
# 9287           64      29221         54         42                  RB CB
# 9677           19           66+5     51         61                  LW ST
# 9786           17         74          61+11     57                     ST
# 10322            62+2       74+2       64+1     35                     CM
# 11465       23802         82         30         35                  CB LB
# 11632          11           50+3      45+24      6                     GK
# 11883          17         67         53         50               LW ST RW
# 12032          16         75         19         14                     GK
# 12435          21           70+1     51         62                     ST
# 14165            64+1       68+1       44+1     22               LB CB RB
# 14311          17           71+3     48         48                     ST
# 14511          52           37+5       66+1     48                     CM
# 14838            33+2       32+2     52         46                 CAM LM
# 14972          73      20090           37+1  12055                 CDM CB
# 15344          34         57           58+3     39               RM LM LW
# 15360          20           66+6     47         62                     ST
# 16123          54      16711         39         24                     RB
# 17506          54           72+3     44         42                 CDM CM
# 17764          45         54         42         41                  RM RB
#
# [17981 rows x 39 columns]

# %%
df_filtered = df[df.Balance<=100]

# %%
df_filtered.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B88EF35550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B88EF8C9E8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B88F9C3EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B88F9FB4A8>]],
#       dtype=object)

# %%
df_filtered.groupby("Age").mean().reset_index().plot.scatter("Age","Balance")
